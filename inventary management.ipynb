# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.DataFrame({"Cust_ID":[101,102,103,104,105,106,107],
                   "Cust_Name":["Ayush","Piyush",np.nan,"Rahul","Sam",np.nan,"Raj"],
                   "P_Name":["Facewash","Soap","Toothpaste","Cookies",np.nan,"Cereals","Books"],
                   "P_Cost":[70,60,45,np.nan,50,110,60],
                   "P_Quantity":[2,5,1,5,3,4,np.nan],
                   "Pay_Mode":["Cash","Credit Card","Credit Card",np.nan,"Cash",np.nan,"Cash"]})
print(df)
# Out:
#    Cust_ID Cust_Name      P_Name  P_Cost  P_Quantity     Pay_Mode
# 0      101     Ayush    Facewash    70.0         2.0         Cash
# 1      102    Piyush        Soap    60.0         5.0  Credit Card
# 2      103       NaN  Toothpaste    45.0         1.0  Credit Card
# 3      104     Rahul     Cookies     NaN         5.0          NaN
# 4      105       Sam         NaN    50.0         3.0         Cash
# 5      106       NaN     Cereals   110.0         4.0          NaN
# 6      107       Raj       Books    60.0         NaN         Cash

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Cust_ID     7 non-null      int64
#  1   Cust_Name   5 non-null      object
#  2   P_Name      6 non-null      object
#  3   P_Cost      6 non-null      float64
#  4   P_Quantity  6 non-null      float64
#  5   Pay_Mode    5 non-null      object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 468.0+ bytes

# %%
df.describe()
# Out:
#           Cust_ID      P_Cost  P_Quantity
# count    7.000000    6.000000    6.000000
# mean   104.000000   65.833333    3.333333
# std      2.160247   23.327380    1.632993
# min    101.000000   45.000000    1.000000
# 25%    102.500000   52.500000    2.250000
# 50%    104.000000   60.000000    3.500000
# 75%    105.500000   67.500000    4.750000
# max    107.000000  110.000000    5.000000

# %%
df.head()
# Out:
#    Cust_ID Cust_Name      P_Name  P_Cost  P_Quantity     Pay_Mode
# 0      101     Ayush    Facewash    70.0         2.0         Cash
# 1      102    Piyush        Soap    60.0         5.0  Credit Card
# 2      103       NaN  Toothpaste    45.0         1.0  Credit Card
# 3      104     Rahul     Cookies     NaN         5.0          NaN
# 4      105       Sam         NaN    50.0         3.0         Cash

# %%
df.tail()
# Out:
#    Cust_ID Cust_Name      P_Name  P_Cost  P_Quantity     Pay_Mode
# 2      103       NaN  Toothpaste    45.0         1.0  Credit Card
# 3      104     Rahul     Cookies     NaN         5.0          NaN
# 4      105       Sam         NaN    50.0         3.0         Cash
# 5      106       NaN     Cereals   110.0         4.0          NaN
# 6      107       Raj       Books    60.0         NaN         Cash

# %%
df.isnull().sum()
# Out:
# Cust_ID       0
# Cust_Name     2
# P_Name        1
# P_Cost        1
# P_Quantity    1
# Pay_Mode      2
# dtype: int64

# %%
df["Cust_Name"] = df["Cust_Name"].fillna("x")
print(df)
# Out:
#    Cust_ID Cust_Name      P_Name  P_Cost  P_Quantity     Pay_Mode
# 0      101     Ayush    Facewash    70.0         2.0         Cash
# 1      102    Piyush        Soap    60.0         5.0  Credit Card
# 2      103         x  Toothpaste    45.0         1.0  Credit Card
# 3      104     Rahul     Cookies     NaN         5.0          NaN
# 4      105       Sam         NaN    50.0         3.0         Cash
# 5      106         x     Cereals   110.0         4.0          NaN
# 6      107       Raj       Books    60.0         NaN         Cash

# %%
plt.scatter(df["P_Cost"], df["P_Quantity"])
plt.xlabel("Product Cost")
plt.ylabel("Product Quantity")
plt.title("Scatter Plot: Product Cost vs Quantity")
plt.grid(True)
plt.show()

# %%
plt.hist(df["P_Cost"].dropna())
plt.xlabel("Product Cost")
plt.ylabel("Frequency")
plt.title("Histogram of Product Cost")
plt.show()

# %%
plt.boxplot(df["P_Cost"].dropna())
plt.ylabel("Product Cost")
plt.title("Box Plot of Product Cost")
plt.show()

# %%
df["Pay_Mode"].value_counts().plot(kind="bar")
plt.xlabel("Payment Mode")
plt.ylabel("Count")
plt.title("Bar Graph of Payment Modes")
plt.show()

# %%
plt.plot(df["Cust_ID"], df["P_Cost"])
plt.xlabel("Customer ID")
plt.ylabel("Product Cost")
plt.title("Line Plot: Customer ID vs Product Cost")
plt.show()
